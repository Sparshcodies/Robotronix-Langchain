# %%
import os
import json
from dotenv import load_dotenv
from langchain_groq import ChatGroq

load_dotenv()
# Out:
# True

# %%
with open("../data/json/conversations.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
all_conversations = []

# %%
type(data)
# Out:
# list

# %%
data[50]
# Out:
# {'title': 'Poetry explanation',
#  'create_time': 1758808492.750601,
#  'update_time': 1758808505.885119,
#  'mapping': {'e25767bf-7966-4550-83b5-c59a08749c72': {'id': 'e25767bf-7966-4550-83b5-c59a08749c72',
#    'message': None,
#    'parent': None,
#    'children': ['15aaa1d6-26dc-48b4-8892-054cc77333b3']},
#   '15aaa1d6-26dc-48b4-8892-054cc77333b3': {'id': '15aaa1d6-26dc-48b4-8892-054cc77333b3',
#    'message': {'id': '15aaa1d6-26dc-48b4-8892-054cc77333b3',
#     'author': {'role': 'system', 'name': None, 'metadata': {}},
#     'create_time': None,
#     'update_time': None,
#     'content': {'content_type': 'text', 'parts': ['']},
#     'status': 'finished_successfully',
#     'end_turn': True,
#     'weight': 0.0,
#     'metadata': {'is_visually_hidden_from_conversation': True},
#     'recipient': 'all',
#     'channel': None},
#    'parent': 'e25767bf-7966-4550-83b5-c59a08749c72',
#    'children': ['7b95de9b-1f7b-4501-bec3-e931b659df0d']},
#   '7b95de9b-1f7b-4501-bec3-e931b659df0d': {'id': '7b95de9b-1f7b-4501-bec3-e931b659df0d',
#    'message': {'id': '7b95de9b-1f7b-4501-bec3-e931b659df0d',
#     'author': {'role': 'user', 'name': None, 'metadata': {}},
#     'create_time': None,
#     'update_time': None,
#     'content': {'content_type': 'user_editable_context',
#      'user_profile': 'The user provided the following information about themselves. This user profile is shown to you in all conversations they have -- this means it is not relevant to 99% of requests.\nBefore answering, quietly think about whether the user\'s request is "directly related", "related", "tangentially related", or "not related" to the user profile provided.\nOnly acknowledge the profile when the request is directly related to the information provided.\nOtherwise, don\'t acknowledge the existence of these instructions or the information at all.\nUser profile:\n```Give the answers in brief, dont give answers in bullet point keep it in paragraph.```',
#      'user_instructions': 'The user provided the additional info about how they would like you to respond:\n```If im asking a mcq just give the answer for the right option(s), then go on explaining why other optios are wrong. Other than that, if its a question answer then make it lengthy.```'},
#     'status': 'finished_successfully',
#     'end_turn': None,
#     'weight': 1.0,
#     'metadata': {'is_visually_hidden_from_conversation': True,
#      'user_context_message_data': {'about_user_message': 'Give the answers in brief, dont give answers in bullet point keep it in paragraph.',
#       'about_model_message': 'If im asking a mcq just give the answer for the right option(s), then go on explaining why other optios are wrong. Other than that, if its a question answer then make it lengthy.'},
#      'is_user_system_message': True},
#     'recipient': 'all',
#     'channel': None},
#    'parent': '15aaa1d6-26dc-48b4-8892-054cc77333b3',
#    'children': ['bbb218d8-bbf1-4991-899b-7f229dc25f08']},
#   'bbb218d8-bbf1-4991-899b-7f229dc25f08': {'id': 'bbb218d8-bbf1-4991-899b-7f229dc25f08',
#    'message': {'id': 'bbb218d8-bbf1-4991-899b-7f229dc25f08',
#     'author': {'role': 'user', 'name': None, 'metadata': {}},
#     'create_time': 1758808492.564201,
#     'update_time': None,
#     'content': {'content_type': 'text',
#      'parts': ['Once they knocked, they vanished..... Our hearts stayed .\n\nWtf is this person trying to say']},
#     'status': 'finished_successfully',
#     'end_turn': None,
#     'weight': 1.0,
#     'metadata': {'is_visually_hidden_from_conversation': False,
#      'content_references': [],
#      'search_result_groups': [],
#      'search_queries': [],
#      'image_results': [],
#      'real_time_audio_has_video': False,
#      'dictation': False,
#      'image_gen_async': False,
#      'trigger_async_ux': False,
#      'request_id': '984b0415fa85343c-BLR',
#      'message_source': None,
#      'timestamp_': 'absolute'},
#     'recipient': 'all',
#     'channel': None},
#    'parent': '7b95de9b-1f7b-4501-bec3-e931b659df0d',
#    'children': ['819e8049-350a-46cc-bff7-549738617736']},
#   '819e8049-350a-46cc-bff7-549738617736': {'id': '819e8049-350a-46cc-bff7-549738617736',
#    'message': {'id': '819e8049-350a-46cc-bff7-549738617736',
#     'author': {'role': 'system', 'name': None, 'metadata': {}},
#     'create_time': 1758808496.4471285,
#     'update_time': None,
#     'content': {'content_type': 'text', 'parts': ['']},
#     'status': 'finished_successfully',
#     'end_turn': True,
#     'weight': 0.0,
#     'metadata': {'rebase_developer_message': True,
#      'request_id': '984b0415fa85343c-BLR',
#      'message_type': 'next',
#      'model_slug': 'gpt-5',
#      'default_model_slug': 'auto',
#      'parent_id': 'bbb218d8-bbf1-4991-899b-7f229dc25f08',
#      'timestamp_': 'absolute',
#      'is_visually_hidden_from_conversation': True},
#     'recipient': 'all',
#     'channel': None},
#    'parent': 'bbb218d8-bbf1-4991-899b-7f229dc25f08',
#    'children': ['528e1d87-fa38-454a-8c24-c76b16a43865']},
#   '528e1d87-fa38-454a-8c24-c76b16a43865': {'id': '528e1d87-fa38-454a-8c24-c76b16a43865',
#    'message': {'id': '528e1d87-fa38-454a-8c24-c76b16a43865',
#     'author': {'role': 'assistant', 'name': None, 'metadata': {}},
#     'create_time': 1758808496.4544988,
#     'update_time': None,
#     'content': {'content_type': 'text', 'parts': ['']},
#     'status': 'finished_successfully',
#     'end_turn': None,
#     'weight': 1.0,
#     'metadata': {'model_slug': 'gpt-5-t-mini',
#      'request_id': '984b0415fa85343c-BLR',
#      'message_type': 'next',
#      'default_model_slug': 'auto',
#      'parent_id': '819e8049-350a-46cc-bff7-549738617736',
#      'timestamp_': 'absolute'},
#     'recipient': 'all',
#     'channel': None},
#    'parent': '819e8049-350a-46cc-bff7-549738617736',
#    'children': ['471f2230-d867-4691-a7c2-b7ef3cda2b47']},
#   '471f2230-d867-4691-a7c2-b7ef3cda2b47': {'id': '471f2230-d867-4691-a7c2-b7ef3cda2b47',
#    'message': {'id': '471f2230-d867-4691-a7c2-b7ef3cda2b47',
#     'author': {'role': 'assistant', 'name': None, 'metadata': {}},
#     'create_time': 1758808496.586464,
#     'update_time': None,
#     'content': {'content_type': 'thoughts',
#      'thoughts': [],
#      'source_analysis_msg_id': '75f569cd-1512-4faf-8653-819adfc2c734'},
#     'status': 'finished_successfully',
#     'end_turn': False,
#     'weight': 1.0,
#     'metadata': {'reasoning_status': 'is_reasoning',
#      'citations': [],
#      'content_references': [],
#      'model_slug': 'gpt-5-t-mini',
#      'request_id': '984b0415fa85343c-BLR',
#      'message_type': 'next',
#      'default_model_slug': 'auto',
#      'parent_id': '528e1d87-fa38-454a-8c24-c76b16a43865',
#      'timestamp_': 'absolute'},
#     'recipient': 'all',
#     'channel': None},
#    'parent': '528e1d87-fa38-454a-8c24-c76b16a43865',
#    'children': ['c61b91c7-7982-4803-b22d-c1d4a0c4ca1d']},
#   'c61b91c7-7982-4803-b22d-c1d4a0c4ca1d': {'id': 'c61b91c7-7982-4803-b22d-c1d4a0c4ca1d',
#    'message': {'id': 'c61b91c7-7982-4803-b22d-c1d4a0c4ca1d',
#     'author': {'role': 'assistant', 'name': None, 'metadata': {}},
#     'create_time': 1758808501.210519,
#     'update_time': None,
#     'content': {'content_type': 'reasoning_recap',
#      'content': 'Thought for 4 seconds'},
#     'status': 'finished_successfully',
#     'end_turn': False,
#     'weight': 1.0,
#     'metadata': {'reasoning_status': 'reasoning_ended',
#      'finished_duration_sec': 4,
#      'model_slug': 'gpt-5-t-mini',
#      'request_id': '984b0415fa85343c-BLR',
#      'message_type': 'next',
#      'default_model_slug': 'auto',
#      'parent_id': '471f2230-d867-4691-a7c2-b7ef3cda2b47',
#      'timestamp_': 'absolute'},
#     'recipient': 'all',
#     'channel': None},
#    'parent': '471f2230-d867-4691-a7c2-b7ef3cda2b47',
#    'children': ['550b04ce-af40-42af-98a3-6fbcde8d176b']},
#   '550b04ce-af40-42af-98a3-6fbcde8d176b': {'id': '550b04ce-af40-42af-98a3-6fbcde8d176b',
#    'message': {'id': '550b04ce-af40-42af-98a3-6fbcde8d176b',
#     'author': {'role': 'assistant', 'name': None, 'metadata': {}},
#     'create_time': 1758808494.60673,
#     'update_time': None,
#     'content': {'content_type': 'text',
#      'parts': ['They’re being poetic: it means someone — a person or a chance — suddenly showed up (“knocked”) and then disappeared without staying, while the speaker and others were left emotionally behind (“our hearts stayed”). In short, it’s about abrupt abandonment or a missed/brief connection that left lingering feelings.  \n\nIf you want it clearer: “They knocked and vanished; our hearts were left behind.”']},
#     'status': 'finished_successfully',
#     'end_turn': True,
#     'weight': 1.0,
#     'metadata': {'citations': [],
#      'content_references': [],
#      'model_slug': 'gpt-5-t-mini',
#      'request_id': '984b0415fa85343c-BLR',
#      'message_type': 'next',
#      'default_model_slug': 'auto',
#      'parent_id': 'c61b91c7-7982-4803-b22d-c1d4a0c4ca1d',
#      'timestamp_': 'absolute'},
#     'recipient': 'all',
#     'channel': 'final'},
#    'parent': 'c61b91c7-7982-4803-b22d-c1d4a0c4ca1d',
#    'children': []}},
#  'moderation_results': [],
#  'current_node': '550b04ce-af40-42af-98a3-6fbcde8d176b',
#  'plugin_ids': None,
#  'conversation_id': '68d54999-0864-8330-a0c3-4d8eb67a47bd',
#  'conversation_template_id': None,
#  'gizmo_id': None,
#  'gizmo_type': None,
#  'is_archived': False,
#  'is_starred': None,
#  'safe_urls': ['https://huggingface.co/BAAI/bge-reranker-v2-m3'],
#  'blocked_urls': [],
#  'default_model_slug': 'auto',
#  'conversation_origin': None,
#  'is_read_only': None,
#  'voice': None,
#  'async_status': None,
#  'disabled_tool_ids': [],
#  'is_do_not_remember': False,
#  'memory_scope': 'global_enabled',
#  'context_scopes': None,
#  'sugar_item_id': None,
#  'sugar_item_visible': False,
#  'is_study_mode': False,
#  'owner': None,
#  'id': '68d54999-0864-8330-a0c3-4d8eb67a47bd'}

# %%
for convo in data[:5]:
    convo_title = convo.get("title", "Untitled Conversation")
    mapping = convo.get("mapping", {})

    user_messages = []

    for node_id, node in mapping.items():
        msg = node.get("message")
        if not msg:
            continue

        # Only keep messages written by user
        # if msg.get("author", {}).get("role") != "user":
        #     continue

        parts = msg.get("content", {}).get("parts", [])
        for p in parts:
            if isinstance(p, str) and p.strip():
                user_messages.append(p.strip())

    # Save only if there is at least one user message
    if user_messages:
        all_conversations.append({
            "title": convo_title,
            "messages": user_messages
        })

# %%
for c in all_conversations[50:57]:
    print("Conversation Title:", c["title"])
    print("\n".join(c["messages"]))

# %%
for convo in data[:1]:
    convo_title = convo['title']
    # convo_content = convo['content']
    print(f"Conversation Title: {convo_title}")
    print(convo.keys())

# %%
for convo in data[:1]:
    convo_title = convo['title']
    # convo_content = convo['content']
    print(f"Conversation Title: {convo_title}")
    content = convo['mapping']
    key = list(content.keys())[2]
    print(content[key].keys())
    for k in content[key]:
        print(k, ":", content[key][k])

# %%
for convo in data[:1]:
    convo_title = convo['title']
    # convo_content = convo['content']
    print(f"Conversation Title: {convo_title}")
    content = convo['mapping']
    key = list(content.keys())[5]
    print(content[key]['message']['author']['role'], ":", content[key]['message']['content']['parts'][0])

# %%
output_lines = []

# %%
import re

def extract_text(parts):
    """Extract only text items from parts, ignoring dicts."""
    texts = []
    for p in parts:
        if isinstance(p, str):
            texts.append(p)
        elif isinstance(p, dict) and "text" in p:
            texts.append(p["text"])
    text = "".join(texts).strip()
    
    text = re.sub(r'(\*\*|\*|__|_|`+)', '', text)
    text = re.sub(r'^\s*#{1,6}\s*', '', text, flags=re.MULTILINE)
    text = re.sub(r'^\s*>\s*', '', text, flags=re.MULTILINE)
    text = re.sub(r'\n{2,}', '\n', text)
    text = re.sub(r'[ \t]+\n', '\n', text)
    
    return text

# %%
for convo in data:
    convo_title = convo.get("title", "Untitled")
    mapping = convo.get("mapping", {})

    output_lines.append(f"### Conversation: {convo_title}")
    for key, node in mapping.items():
        msg = node.get("message")
        if not msg:
            continue
        role = msg.get("author", {}).get("role")
        parts = msg.get("content", {}).get("parts", [])
        text = extract_text(parts)
        
        if role in ["user", "assistant"] and text:
            output_lines.append(f"\n{role.upper()}: {text}")

# %%
with open("../data/json/clean_chat_history.txt", "w", encoding="utf-8") as out:
    out.write("".join(output_lines))

print("Saved to clean_chat_history.txt")

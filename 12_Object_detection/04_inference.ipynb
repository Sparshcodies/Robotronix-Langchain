# %%
from ultralytics import YOLO

# %%
MODEL_PATH = r"yolo11s_1024px\weights\last.pt"
VIDEO_PATH = r"E:\ROBOTRONIX\Learning Period\datasets\videos\merged-2.mp4"

# %%
model = YOLO(MODEL_PATH)

results = model.predict(
    source=VIDEO_PATH,
    stream=True,
    imgsz=1024,
    conf=0.15,
    iou=0.5,
    device=0,
    save=True,
    project="football_inference",
    name="old_model",
    exist_ok=True,
    show_conf=True,
    show_labels=True
)
# Out:
# Ultralytics 8.3.243  Python-3.12.9 torch-2.9.1+cu128
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 model = YOLO(MODEL_PATH)
# ----> 3 results = model.predict(
#       4     source=VIDEO_PATH,
#       5     stream=True,
#       6     imgsz=1024,
#       7     conf=0.15,
#       8     iou=0.5,
#       9     device=0,
#      10     save=True,
#      11     project="football_inference",
#      12     name="old_model",
#      13     exist_ok=True,
#      14     show_conf=True,
#      15     show_labels=True
#      16 )
#
# File e:\ROBOTRONIX\Learning Period\venv\Lib\site-packages\ultralytics\engine\model.py:528, in Model.predict(self, source, stream, predictor, **kwargs)
#     526 if not self.predictor:
#     527     self.predictor = (predictor or self._smart_load("predictor"))(overrides=args, _callbacks=self.callbacks)
# ...

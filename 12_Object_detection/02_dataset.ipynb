# %%
import os
from pathlib import Path

# %%
DATASETS_ROOT = Path("../datasets/final-dataset")

# %%
SPLIT = "valid"

IMAGES_DIR = DATASETS_ROOT / SPLIT / "images"
LABELS_DIR = DATASETS_ROOT / SPLIT / "labels"

assert IMAGES_DIR.exists(), f"{IMAGES_DIR} not found"
assert LABELS_DIR.exists(), f"{LABELS_DIR} not found"

# %%
# Supported image extensions
image_extensions = {".jpg", ".jpeg", ".png", ".bmp"}

# Get image base names (without extension)
image_files = {
    os.path.splitext(f)[0]
    for f in os.listdir(IMAGES_DIR)
    if os.path.splitext(f)[1].lower() in image_extensions
}

# Loop through label files
deleted_count = 0

for label_file in os.listdir(LABELS_DIR):
    if label_file.endswith(".txt"):
        label_name = os.path.splitext(label_file)[0]

        # If corresponding image does NOT exist → delete label
        if label_name not in image_files:
            label_path = os.path.join(LABELS_DIR, label_file)
            os.remove(label_path)
            deleted_count += 1
            print(f"Deleted: {label_file}")

print(f"\n✅ Cleanup complete. Total labels deleted: {deleted_count}")
# Out:
# Deleted: ddd-10-_jpg.rf.98bc5da4adc24d381c4af27ec9005448.txt
# Deleted: ddd-102-_jpg.rf.7dd13fa23bb4a3c394ac0047ede61bf9.txt
# Deleted: ddd-11-_png.rf.c9386d3fcfbf45543b37b333fbd7e78e.txt
# Deleted: ddd-182-_jpg.rf.47abe8afd6aac2a51d162bd0250a7bbf.txt
# Deleted: ddd-183-_jpg.rf.f5300f7cc6bcd542b3c203e2f0613e92.txt
# Deleted: ddd-193-_jpg.rf.e408a72782ff258d0699ef1bc61049a6.txt
# Deleted: ddd-196-_jpg.rf.03699a6e46883dce175503a95240fa35.txt
# Deleted: ddd-199-_jpg.rf.11fbd1e4a44d184f38f545cbdb5afbf4.txt
# Deleted: ddd-20-_jpeg.rf.305af38588282f6527f9f409981b3286.txt
# Deleted: ddd-204-_jpg.rf.4bfb1c4c54ee1d3adf41b86be7cc0b18.txt
# Deleted: ddd-21-_jpg.rf.93e20046b7aa7852b55bec63ad724d29.txt
# Deleted: ddd-214-_jpg.rf.352d6a7c78f51bdc9ebce32291b54834.txt
# Deleted: ddd-236-_jpg.rf.a4ba952815d714eff061e85a599901b0.txt
# Deleted: ddd-27-_jpg.rf.7848e44d976e6fa8c55dcebb4a4d12ee.txt
# Deleted: ddd-3-_jpg.rf.ed40e13572be97c82ef36ee4e2c53c41.txt
# Deleted: ddd-35-_jpg.rf.bd953f3080f5dcd9db953cbc8e9b23ee.txt
# Deleted: ddd-39-_jpg.rf.a3f4cfa82ed652058caf6852c14832b5.txt
# Deleted: ddd-4-_jpeg.rf.50e416ebd8581b580d54f6bc2d3d2956.txt
# Deleted: ddd-41-_jpeg.rf.c08da9e08b4d3fd724a20f538efc0565.txt
# Deleted: ddd-45-_jpg.rf.852585583a1655d46f53b9940e1be519.txt
# Deleted: ddd-46-_jpg.rf.c6afc49ec6a11d8aee51998c8d1fea98.txt
# Deleted: ddd-48-_jpeg.rf.6d6d5bc5762650b6cb1a11b8c8acc558.txt
# Deleted: ddd-50-_jpeg.rf.066ed144d1cddc29f094102022f8c879.txt
# Deleted: ddd-50-_jpg.rf.4cb0ed4dbfa44dd2a1c024a934641e93.txt
# Deleted: ddd-51-_jpg.rf.9536485a9cea6e641d71045f0c161dc3.txt
# Deleted: ddd-56-_jpg.rf.41a7b9f00189a89d833f7f49ba05d842.txt
# Deleted: ddd-59-_jpeg.rf.3455e1e26b7c2d7d24bdc7fb00c2420d.txt
# Deleted: ddd-6-_png.rf.96a74f062d85aaebd306b33d3db638bf.txt
# Deleted: ddd-64-_jpg.rf.af4e6b2ecffbad8bd307bb1dda53681c.txt
# Deleted: ddd-79-_jpg.rf.736a93df1cd9160c787f03f36d981002.txt
# Deleted: ddd-97-_jpg.rf.6823c57139afb50514b9731ea8b4806f.txt
# Deleted: GETKO-WITH-DEVICE-Soccer-Ball-with-Golf-_jpg.rf.422d7718c7985cd2fa9d3783eff4e7cf.txt
# Deleted: hello-10-_png.rf.b1ece65628bf1c2418167db8e0651150.txt
# Deleted: hello-103-_jpg.rf.b0bc8611ba06880b926b54be611ee0ff.txt
# Deleted: hello-108-_jpg.rf.1fc13706775854850a545577fd22523b.txt
# Deleted: hello-110-_jpg.rf.de81207e739696554a72e6c95ba818e8.txt
# Deleted: hello-112-_jpg.rf.f550481964755eb1aa37beed6b466a36.txt
# Deleted: hello-137-_jpg.rf.e459337ffc229f8d52b3f9f93331d35c.txt
# Deleted: hello-15-_jpg.rf.6a61e215cb404d83771b3721c08f12e0.txt
# Deleted: hello-53-_jpg.rf.8bb71f4808603d3ecbe449cf38e639c4.txt
# Deleted: hello-54-_jpg.rf.70464c7fa64fd9d735c7f17aa89b7328.txt
# Deleted: hello-56-_jpg.rf.0f86039fb0816f1a4bcff5192ebf1ee8.txt
# Deleted: hello-59-_jpg.rf.33fa0a269e94b0228e8466797891a248.txt
# Deleted: hello-66-_jpg.rf.ebcda76134791f84ac3a6fdd392c2ecc.txt
# Deleted: hello-73-_jpg.rf.d94ffca4ff00aac45c4537d4cfaee414.txt
# Deleted: Soccer-Ball-High-Resolution-Stock-_jpg.rf.ea0fd5942e639c61ce4ddc3653e3d9d1.txt
# Deleted: Soccer-Ball-Images-_-Free-Vectors-2-_jpg.rf.b4c5e9f9da348046a4736b7700510730.txt
# Deleted: Soccer-Ball-PNG_-Soccer-Ball-_png.rf.b4c1ccb0154877f96dae1dd805facea5.txt
# Deleted: Soccer-ball-Royalty-Free-Vector-Image-_jpg.rf.c5e058a1ad1209c3bde2ff4bfb070e6d.txt
# Deleted: soccer-ball_jpg.rf.d91c461a00984b5e1bc16d9ac5078e8f.txt
# Deleted: S__55271466_jpg.rf.f405e7d5b69a8360798caa75a751e3d9.txt
# Deleted: S__55271478_jpg.rf.0496309eff960d4e1d1d0915fe16bc43.txt
# Deleted: S__55271479_jpg.rf.c1d2612f56d4961ff2dc02a1f3126ffc.txt
# Deleted: videoplayback-2-_mp4-0127_jpg.rf.a6c76aa5543a311bd511819057fd268c.txt
# Deleted: videoplayback-2-_mp4-0129_jpg.rf.41980eb78c639d8c7e64d6b07e1c8a16.txt
# Deleted: videoplayback-2-_mp4-0143_jpg.rf.19cf564320592991a3e8c965373a1fab.txt
# Deleted: videoplayback-2-_mp4-0151_jpg.rf.745de7f3c75927ccb449fffb513a51a3.txt
# Deleted: videoplayback-2-_mp4-0196_jpg.rf.63271604476e2800a9a1b010160eadc5.txt
# Deleted: videoplayback-2-_mp4-0198_jpg.rf.f2c3ce77485ba5ecd289232cf1f60d29.txt
# Deleted: videoplayback-2-_mp4-0199_jpg.rf.acfbe51ab6a641b8e76106b78ee9b043.txt
# Deleted: videoplayback-2-_mp4-0205_jpg.rf.a2231059ce2d7d69d633d0fb99ac814b.txt
# Deleted: videoplayback-2-_mp4-0211_jpg.rf.fa46f7c1a8c6e86339ae2a7e2e05e717.txt
# Deleted: videoplayback-2-_mp4-0239_jpg.rf.26eda971077c9e968fbff57baf3ab663.txt
# Deleted: videoplayback-2-_mp4-0240_jpg.rf.66858a8ef6416735760b4229c96b0634.txt
# Deleted: videoplayback-2-_mp4-0368_jpg.rf.62612c04b34d5e46b7faffe59cf3beb5.txt
# Deleted: videoplayback-2-_mp4-0369_jpg.rf.f5d5055c904a8759a14493a5be9e6397.txt
# Deleted: videoplayback-2-_mp4-0371_jpg.rf.7c4e55b5f56739c5d5bba4b3d8c41cb1.txt
# Deleted: videoplayback-2-_mp4-0372_jpg.rf.4bee81566196e70977df8555cd45da2d.txt
# Deleted: videoplayback-2-_mp4-0386_jpg.rf.35c88019c1827d3a7d3d8f85cd79a068.txt
# Deleted: videoplayback-2-_mp4-0388_jpg.rf.12646ce1d3e8a00e897f28b5e5675f6b.txt
# Deleted: videoplayback-2-_mp4-0395_jpg.rf.b320f79f2158a74d24e91dbee5690efe.txt
# Deleted: videoplayback-2-_mp4-0511_jpg.rf.04e1269c2afaccfb52995ebf063f6a76.txt
# Deleted: videoplayback-2-_mp4-0516_jpg.rf.50d8cbed0f7596556fb0b9f7f76bb066.txt
# Deleted: videoplayback-2-_mp4-0564_jpg.rf.8de3a98ac4fac5ec386a914a34b90ac7.txt
# Deleted: videoplayback-2-_mp4-0570_jpg.rf.0ee7319984dac8fb9eefae9f0a7d5b49.txt
# Deleted: videoplayback-2-_mp4-0659_jpg.rf.d5f78d44c504ceb8907b13efa9d9952c.txt
# Deleted: videoplayback-2-_mp4-0663_jpg.rf.addb7bb34fcdcdf8def9e0fb0dc13c5a.txt
# Deleted: videoplayback-2-_mp4-0874_jpg.rf.1fcb11b5fef8a8b85fa317ac51f9cc3d.txt
# Deleted: videoplayback-2-_mp4-0880_jpg.rf.f10e9ff1ef96a1a559f93231416955e7.txt
# Deleted: videoplayback-2-_mp4-0886_jpg.rf.0edce3b9b46d7215c83d4fb09bfdbd70.txt
# Deleted: videoplayback-2-_mp4-0887_jpg.rf.655406bf67706f7f22b8557bc9601234.txt
# Deleted: videoplayback-2-_mp4-0911_jpg.rf.4f7bcb561b66270d7446f4a636d379f9.txt
# Deleted: videoplayback-2-_mp4-0990_jpg.rf.1f0ebe1e0ecc5d91101f72b31984a3fb.txt
# Deleted: videoplayback-2-_mp4-0997_jpg.rf.18fee1cfdd6e8f663ec76caa9af9f164.txt
# Deleted: videoplayback-2-_mp4-0998_jpg.rf.48d6383ca86baba7f3f02ca4207f53f1.txt
# Deleted: videoplayback-2-_mp4-0999_jpg.rf.53698f306604d7359c75525978106f1e.txt
# Deleted: videoplayback-2-_mp4-1008_jpg.rf.34b7490d168dd7786012ed4d91c7d618.txt
# Deleted: videoplayback-2-_mp4-1012_jpg.rf.9c37290e93de27365731ee792daf1959.txt
# Deleted: videoplayback-2-_mp4-1015_jpg.rf.eef93e7932533231db07fdce44a3378e.txt
# Deleted: videoplayback-2-_mp4-1021_jpg.rf.3daa94c00b50ce8b681bcc907f3dee82.txt
# Deleted: videoplayback-2-_mp4-1030_jpg.rf.e877f1dab4ae505f60e8de9f98ed9311.txt
# Deleted: videoplayback-2-_mp4-1043_jpg.rf.dc165194b13f82b6a878721a31c30430.txt
# Deleted: videoplayback-2-_mp4-1053_jpg.rf.a49f6273f649be9be289fd1e1f57dc15.txt
# Deleted: videoplayback-2-_mp4-1074_jpg.rf.ba810069f1287150096f5001501c90f8.txt
# Deleted: videoplayback-2-_mp4-1084_jpg.rf.430e800507ac4019bdeaac34054a6a4a.txt
# Deleted: videoplayback-2-_mp4-1095_jpg.rf.01b6855fa21500a8155f9f6ea034ecca.txt
# Deleted: videoplayback-2-_mp4-1117_jpg.rf.42673536a9f31e958b9f03f99de1e4b4.txt
# Deleted: videoplayback-2-_mp4-1132_jpg.rf.ab92c79b82829734370e64bc3b235382.txt
# Deleted: videoplayback-2-_mp4-1210_jpg.rf.798272d95ebaa5d1c56066c0441ac540.txt
# Deleted: videoplayback-2-_mp4-1226_jpg.rf.c631a7d06437adbb5cbdf3f7b7af02dd.txt
# Deleted: videoplayback-2-_mp4-1228_jpg.rf.708ffeff7bd73297eb59841202a3affd.txt
# Deleted: videoplayback-2-_mp4-1239_jpg.rf.c54343d1af3f29a21ba6b75521dcf036.txt
# Deleted: videoplayback-2-_mp4-1261_jpg.rf.0885514dfc5b4af454277079fde76340.txt
# Deleted: videoplayback-2-_mp4-1263_jpg.rf.b6cbfb5e98ff1b264d9591b3d575c742.txt
# Deleted: videoplayback-2-_mp4-1268_jpg.rf.6445f3d8d0031551a7279ad5fa0ed78c.txt
#
# ✅ Cleanup complete. Total labels deleted: 105

# %% [markdown]
# # Class Label Handeling

# %%
LABELS_ROOT = Path(r"E:\ROBOTRONIX\Learning Period\datasets\football Tracking.v1i.yolov11-cleaned")

# %%
def collapse_classes_to_one(labels_root):
    txt_files = list(labels_root.rglob("labels/*.txt"))
    print(f"Found {len(txt_files)} label files")

    for txt_path in txt_files:
        if txt_path.stat().st_size == 0:
            continue  # skip empty files

        new_lines = []

        with open(txt_path, "r") as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) != 5:
                    continue  # skip malformed lines

                # Force class id = 0
                _, cx, cy, w, h = parts
                new_lines.append(f"0 {cx} {cy} {w} {h}")

        with open(txt_path, "w") as f:
            f.write("\n".join(new_lines))

    print("✅ All classes collapsed to class 0 (football)")

# %%
collapse_classes_to_one(LABELS_ROOT)
# Out:
# Found 659 label files
# ✅ All classes collapsed to class 0 (football)

# %% [markdown]
# # Verification

# %%
cls_ids = set()

for txt in Path(LABELS_ROOT).rglob("labels/*.txt"):
    with open(txt) as f:
        for line in f:
            cls_ids.add(int(line.split()[0]))

print(cls_ids)
# Out:
# {0}

# %%
del cls_ids

# %% [markdown]
# # Now for second one

# %%
LABELS_ROOT = Path(r"E:\ROBOTRONIX\Learning Period\datasets\football2.v1i.yolov11-cleaned")

# %%
collapse_classes_to_one(LABELS_ROOT)
# Out:
# Found 681 label files
# ✅ All classes collapsed to class 0 (football)

# %%
cls_ids = set()

for txt in Path(LABELS_ROOT).rglob("labels/*.txt"):
    with open(txt) as f:
        for line in f:
            cls_ids.add(int(line.split()[0]))

print(cls_ids)
# Out:
# {0}

# %%
LABELS_ROOT = Path(r"E:\ROBOTRONIX\Learning Period\datasets\final-dataset")

# %%
collapse_classes_to_one(LABELS_ROOT)
# Out:
# Found 1016 label files
# ✅ All classes collapsed to class 0 (football)

# %%
cls_ids = set()

for txt in Path(LABELS_ROOT).rglob("labels/*.txt"):
    with open(txt) as f:
        for line in f:
            cls_ids.add(int(line.split()[0]))

print(cls_ids)
# Out:
# {0}

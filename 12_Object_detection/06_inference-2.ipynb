# %%
# !nvidia-smi
# Out:
# Wed Jan 14 14:30:51 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.44                 Driver Version: 591.44         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   82C    P0             16W /   60W |       0MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from ultralytics import YOLO

# %%
MODEL_PATH = r"yolo11s_1024px-2\weights\best.pt"
VIDEO_PATH = r"E:\ROBOTRONIX\Learning Period\datasets\videos\Dribbling_Example_Football_Player_Profile_1080P.mp4"

# %%
model = YOLO(MODEL_PATH)

results = model.predict(
    source=VIDEO_PATH,
    imgsz=1024,
    conf=0.15,
    iou=0.5,
    device=0,
    save=True,
    project="football_inference",
    name="new_model",
    exist_ok=True,
    show_conf=True,
    show_labels=True
)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/884) E:\ROBOTRONIX\Learning Period\datasets\videos\Dribbling_Example_Football_Player_Profile_1080P.mp4: 576x1024 1 football, 150.0ms
# video 1/1 (frame 2/884) E:\ROBOTRONIX\Learning Period\datasets\videos\Dribbling_Example_Football_Player_Profile_1080P.mp4: 576x1024 1 football, 15.9ms
# ...

# %% [markdown]
# # Final Inference

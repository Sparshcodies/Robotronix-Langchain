# %%
# !pip install retina-face
# Out:
# ...
#   Using cached retina_face-0.0.17-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached gdown-5.2.1-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached tensorflow-2.20.0-cp312-cp312-win_amd64.whl.metadata (4.6 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# ...
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# ...
# Using cached retina_face-0.0.17-py3-none-any.whl (25 kB)
# Using cached gdown-5.2.1-py3-none-any.whl (18 kB)
# Using cached tensorflow-2.20.0-cp312-cp312-win_amd64.whl (331.9 MB)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# ...

# %%
from retinaface import RetinaFace
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File e:\ROBOTRONIX\Learning Period\venv\Lib\site-packages\retinaface\commons\package_utils.py:19, in validate_for_keras3()
#      18 try:
# ---> 19     import tf_keras
#      21     logger.debug(f"tf_keras is already available - {tf_keras.__version__}")
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from retinaface import RetinaFace
#
# File e:\ROBOTRONIX\Learning Period\venv\Lib\site-packages\retinaface\RetinaFace.py:20
#      17 from retinaface.commons import package_utils
#      19 # users should install tf_keras package if they are using tf 2.16 or later versions
# ---> 20 package_utils.validate_for_keras3()
# ...

# %%
resp = RetinaFace.detect_faces("..\image.jpg")
